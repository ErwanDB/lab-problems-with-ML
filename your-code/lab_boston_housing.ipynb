# %% [markdown]
# # Understanding Over & Underfitting
# ## Predicting Boston Housing Prices

# %% [markdown]
# ## Getting Started
# In this project, you will use the Boston Housing Prices dataset to build several models to predict the prices of homes with particular qualities from the suburbs of Boston, MA.
# We will build models with several different parameters, which will change the goodness of fit for each.

# %% [markdown]
# ---
# ## Data Exploration
# Since we want to predict the value of houses, the **target variable**, `'MEDV'`, will be the variable we seek to predict.

# %% [markdown]
# ### Import and explore the data. Clean the data for outliers and missing values.

# %%
import numpy as np
import pandas as pd

houses = pd.read_csv('../data/boston_data.csv')
houses
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis   rad    tax  \
# 0     0.15876   0.0  10.81   0.0  0.413  5.961   17.5  5.2873   4.0  305.0
# 1     0.10328  25.0   5.13   0.0  0.453  5.927   47.2  6.9320   8.0  284.0
# 2     0.34940   0.0   9.90   0.0  0.544  5.972   76.7  3.1025   4.0  304.0
# 3     2.73397   0.0  19.58   0.0  0.871  5.597   94.9  1.5257   5.0  403.0
# 4     0.04337  21.0   5.64   0.0  0.439  6.115   63.0  6.8147   4.0  243.0
# ..        ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 399   9.32909   0.0  18.10   0.0  0.713  6.185   98.7  2.2616  24.0  666.0
# 400  51.13580   0.0  18.10   0.0  0.597  5.757  100.0  1.4130  24.0  666.0
# 401   0.01501  90.0   1.21   1.0  0.401  7.923   24.8  5.8850   1.0  198.0
# 402   0.02055  85.0   0.74   0.0  0.410  6.383   35.7  9.1876   2.0  313.0
# 403   0.08244  30.0   4.93   0.0  0.428  6.481   18.5  6.1899   6.0  300.0
#
#      ptratio   black  lstat  medv
# ...

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     404 non-null    float64
#  1   zn       404 non-null    float64
#  2   indus    404 non-null    float64
#  3   chas     404 non-null    float64
#  4   nox      404 non-null    float64
#  5   rm       404 non-null    float64
#  6   age      404 non-null    float64
#  7   dis      404 non-null    float64
#  8   rad      404 non-null    float64
#  9   tax      404 non-null    float64
#  10  ptratio  404 non-null    float64
#  11  black    404 non-null    float64
#  12  lstat    404 non-null    float64
#  13  medv     404 non-null    float64
# dtypes: float64(14)
# memory usage: 44.3 KB

# %% [markdown]
# ### Next, we want to explore the data. Pick several varibables you think will be most correlated with the prices of homes in Boston, and create plots that show the data dispersion as well as the regression line of best fit.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

matrix = houses.corr().abs()

upper = matrix.where(np.triu(np.ones(matrix.shape),k=1).astype(np.bool))
plt.figure(figsize=(12,8))
sns.heatmap(upper, annot=True,cmap="YlGnBu", vmin=0, vmax=1)
plt.show()

# %%
high_corr = houses.drop(["crim","zn","chas","nox","age","dis","rad","black"],axis=1)

# %%
#plt.figure(figsize=(12,8))
sns.pairplot(high_corr,diag_kind="kde", kind="reg")
plt.show()

# %% [markdown]
# ### What do these plots tell you about the relationships between these variables and the prices of homes in Boston? Are these the relationships you expected to see in these variables?

# %%
# Your response here
"""Price is nearly normally distributed"""
# Out:
# 'Price is nearly normally distributed'

# %% [markdown]
# ### Make a heatmap of the remaining variables. Are there any variables that you did not consider that have very high correlations? What are they?

# %%
# Your response here

# %% [markdown]
# ### Calculate Statistics
# Calculate descriptive statistics for housing price. Include the minimum, maximum, mean, median, and standard deviation.

# %%
houses.describe()
# Out:
#              crim          zn       indus        chas         nox         rm  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.00000
# mean     3.730912   10.509901   11.189901    0.069307    0.556710    6.30145
# std      8.943922   22.053733    6.814909    0.254290    0.117321    0.67583
# min      0.006320    0.000000    0.460000    0.000000    0.392000    3.56100
# 25%      0.082382    0.000000    5.190000    0.000000    0.453000    5.90275
# 50%      0.253715    0.000000    9.795000    0.000000    0.538000    6.23050
# 75%      4.053158   12.500000   18.100000    0.000000    0.631000    6.62925
# max     88.976200   95.000000   27.740000    1.000000    0.871000    8.78000
#
#               age         dis         rad         tax     ptratio       black  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    68.601733    3.799666    9.836634  411.688119   18.444554  355.068243
# ...

# %% [markdown]
# ----
#
# ## Developing a Model

# %% [markdown]
# ### Implementation: Define a Performance Metric
# What is the performance metric with which you will determine the performance of your model? Create a function that calculates this performance metric, and then returns the score.

# %%
from sklearn.metrics import r2_score

def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    # Your code here:
    x = r2_score(y_true, y_predict)
    return x

# %% [markdown]
# ### Implementation: Shuffle and Split Data
# Split the data into the testing and training datasets. Shuffle the data as well to remove any bias in selecting the train and test.

# %%
from sklearn.model_selection import train_test_split

train,test=train_test_split(houses,train_size=0.8,shuffle=True)

X_train = train.drop(["medv"],axis=1)
X_test = test.drop(["medv"],axis=1)

y_train = train["medv"]
y_test = test["medv"]

# %% [markdown]
# ----
#
# ## Analyzing Model Performance
# Next, we are going to build a Random Forest Regressor, and test its performance with several different parameter settings.

# %% [markdown]
# ### Learning Curves
# Lets build the different models. Set the max_depth parameter to 2, 4, 6, 8, and 10 respectively.

# %%
from sklearn.ensemble import RandomForestRegressor

# Five separate RFR here with the given max depths

RF_2 = RandomForestRegressor(max_depth=2)
RF_2.fit(X_train,y_train)

RF_4 = RandomForestRegressor(max_depth=4)
RF_4.fit(X_train,y_train)

RF_6 = RandomForestRegressor(max_depth=6)
RF_6.fit(X_train,y_train)

RF_8 = RandomForestRegressor(max_depth=8)
RF_8.fit(X_train,y_train)

RF_10 = RandomForestRegressor(max_depth=10)
RF_10.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=10)

# %% [markdown]
# Now, plot the score for each tree on the training set and on the testing set.

# %%
# Produce a plot with the score for the testing and training for the different max depths
score_train = []
score_test = []

for i in range(2,12,2):
    model = RandomForestRegressor(max_depth=i)
    model.fit(X_train,y_train)
    score_train.append(r2_score(y_train,model.predict(X_train)))
    score_test.append(r2_score(y_test,model.predict(X_test)))

#plt.figure(figsize=(10,8))
plt.plot(range(2,12,2),score_train)
plt.plot(range(2,12,2),score_test)
plt.xlabel('max depth random forest')
plt.ylabel('r2 score')
plt.legend(['train','test'])
plt.show()

# %% [markdown]
# What do these results tell you about the effect of the depth of the trees on the performance of the model?

# %%
# Your response here
"""Optimum depth is 8 as the test set score start decreasing after this threshold"""

# %% [markdown]
# ### Bias-Variance Tradeoff
# When the model is trained with a maximum depth of 1, does the model suffer from high bias or from high variance? How about when the model is trained with a maximum depth of 10?

# %%
# Your response here
"""With a maximum depth of 1, the model suffer high bias while with a max depth of 10,
the model suffer high variance."""

# %% [markdown]
# ### Best-Guess Optimal Model
# What is the max_depth parameter that you think would optimize the model? Run your model and explain its performance.

# %%
# Your response here
"""best guess is max depth=8"""

# %% [markdown]
# ### Applicability
# *In a few sentences, discuss whether the constructed model should or should not be used in a real-world setting.*
# **Hint:** Some questions to answering:
# - *How relevant today is data that was collected from 1978?*
# - *Are the features present in the data sufficient to describe a home?*
# - *Is the model robust enough to make consistent predictions?*
# - *Would data collected in an urban city like Boston be applicable in a rural city?*

# %%
# Your response here
